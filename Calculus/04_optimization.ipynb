# %% [markdown]
# # Reward function

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Loss function

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### All the points have a derivative of zero because the slope of the tangent line is zero at all points..... and they basically flat

# %% [markdown]
# ### BUT if the the slope keeps going down or up, then maybe...MAYBE there are no minimum or maximun

# %% [markdown]
# But for now these are the minimun and maximum

# %% [markdown]
# ![image.png](attachment:image.png)
