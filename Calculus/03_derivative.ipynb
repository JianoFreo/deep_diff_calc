# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # x = x
# # f(x) = y

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ## This means H is going to get reaally really small

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## you can see the x + h is really close to the x because the h is a small amount. Means we are going to take a tiny step

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## example of limit
#
# ## $\frac{f(x + h) - f(x)}{(x + h) - x}$ = $\frac{1.1999 - 1.2}{4.21 - 4.2}$ = $\frac{-0.0001}{0.01}$ = -0.01

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # definition of a derivative

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## the red line is providing the slope of the black line

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Find the derivative

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
