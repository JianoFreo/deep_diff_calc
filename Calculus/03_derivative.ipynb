# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # x = x
# # f(x) = y

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ## This means H is going to get reaally really small

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## you can see the x + h is really close to the x because the h is a small amount
